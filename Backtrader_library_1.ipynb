# %%
import backtrader as bt
from datetime import datetime
import yfinance as yf

# %%
class testSMACross(bt.SignalStrategy):
    def __init__(self):
        sma=bt.ind.SMA(period=50)
        price=self.data
        crossover=bt.ind.CrossOver(price,sma)
        self.signal_add(bt.SIGNAL_LONG, crossover)

# %%
cerebro=bt.Cerebro()

# %%
cerebro.addstrategy(testSMACross)
# Out:
# 0

# %%
df=yf.download("BTC-USD")
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-04-05  28169.726562  28739.238281  27843.763672  28177.984375
# 2023-04-06  28175.226562  28178.384766  27738.759766  28044.140625
# 2023-04-07  28038.966797  28111.593750  27794.031250  27925.859375
# 2023-04-08  27920.513672  28159.863281  27883.386719  27947.794922
# 2023-04-09  27946.511719  28096.419922  27837.507812  27936.087891
#
#                Adj Close       Volume
# Date
# 2014-09-17    457.334015     21056800
# 2014-09-18    424.440002     34483200
# 2014-09-19    394.795990     37919700
# 2014-09-20    408.903992     36863600
# 2014-09-21    398.821014     26580100
# ...                  ...          ...
# 2023-04-05  28177.984375  17052315986
# 2023-04-06  28044.140625  13837809380
# 2023-04-07  27925.859375  10861680497
# 2023-04-08  27947.794922   9373255556
# 2023-04-09  27936.087891  10117038080
#
# [3127 rows x 6 columns]

# %%
data=bt.feeds.PandasData(dataname=df)

# %%
data

# %%
cerebro.adddata(data)

# %%
cerebro.run()

# %%
cerebro.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# [[<Figure size 640x480 with 5 Axes>]]
