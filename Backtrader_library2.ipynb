# %%
import backtrader as bt
import pandas as pd
import matplotlib
import yfinance as yf

# %%
tsla=yf.download(tickers="TSLA")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tsla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-03-31  197.529999  207.789993  197.199997  207.460007  207.460007
# 2023-04-03  199.910004  202.690002  192.199997  194.770004  194.770004
# 2023-04-04  197.320007  198.740005  190.320007  192.580002  192.580002
# 2023-04-05  190.520004  190.679993  183.759995  185.520004  185.520004
# 2023-04-06  183.080002  186.389999  179.740005  185.059998  185.059998
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %%
tsla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3216 entries, 2010-06-29 to 2023-04-06
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3216 non-null   float64
#  1   High       3216 non-null   float64
#  2   Low        3216 non-null   float64
#  3   Close      3216 non-null   float64
#  4   Adj Close  3216 non-null   float64
#  5   Volume     3216 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 175.9 KB

# %%
data=bt.feeds.PandasData(dataname=tsla)

# %%
data

# %% [markdown]
# # Build the strategy

# %%
class testSTG(bt.Strategy):
     def __init__(self):
        pass
     def next(self):
        pass
    
class testClose(bt.Strategy):
    def __init__(self):
        pass
    def next(self):
        dataclose=self.datas[0].close[0]       #internal referencing slide
        print(dataclose)
        
class testClosei(bt.Strategy):
    def __init__(self):
        self.dataclose=self.datas[0].close    # took dataclose into the initilizer  #init= initilizaer
    def next(self):
        print(self.dataclose[0])
        
       
class testLog(bt.Strategy):     #to notify our trader about trade
    def __init__(self):
        self.dataclose=self.datas[0].close
    def log(self,txt):
        dt=self.datas[0].datetime.datetime()
        print(f'{dt}|{txt}')
    def next(self):
        x= self.dataclose[0]
        self.log(txt=x)

# %%
cerebro=bt.Cerebro()

# %%
cerebro.adddata(data)

# %%
cerebro.addstrategy(testSTG)
# Out:
# 0

# %%
cerebro.run()

# %% [markdown]
# ###  closing price of tesla stock per day.

# %%
cerebro.addstrategy(testClose)
# Out:
# 1

# %%
cerebro.run()
# Out:
# 1.5926669836044312
# 1.5886670351028442
# 1.4639999866485596
# 1.2799999713897705
# 1.0740000009536743
# 1.053333044052124
# 1.1640000343322754
# 1.159999966621399
# 1.136667013168335
# 1.2093329429626465
# 1.3226670026779175
# 1.3259999752044678
# 1.3760000467300415
# 1.4606670141220093
# 1.3533329963684082
# 1.3480000495910645
# 1.399999976158142
# 1.4193329811096191
# 1.3966670036315918
# 1.3700000047683716
# 1.3813329935073853
# 1.3566670417785645
# 1.329332947731018
# 1.3946670293807983
# 1.463333010673523
# 1.4173330068588257
# 1.363332986831665
# 1.305999994277954
# 1.3066669702529907
# 1.2686669826507568
# 1.1933330297470093
# 1.1733330488204956
# 1.2213330268859863
# 1.2519999742507935
# 1.2766669988632202
# 1.2513329982757568
# 1.25266695022583
# 1.273332953453064
# 1.3420000076293945
# 1.2799999713897705
# 1.3266669511795044
# 1.3166669607162476
# 1.3133330345153809
# 1.324666976928711
# 1.2986669540405273
# 1.363332986831665
# 1.4040000438690186
# 1.4033329486846924
# ...

# %%
cerebro.addstrategy(testClosei)
# Out:
# 2

# %%
cerebro.run()
# Out:
# 1.5926669836044312
# 1.5926669836044312
# 1.5886670351028442
# 1.5886670351028442
# 1.4639999866485596
# 1.4639999866485596
# 1.2799999713897705
# 1.2799999713897705
# 1.0740000009536743
# 1.0740000009536743
# 1.053333044052124
# 1.053333044052124
# 1.1640000343322754
# 1.1640000343322754
# 1.159999966621399
# 1.159999966621399
# 1.136667013168335
# 1.136667013168335
# 1.2093329429626465
# 1.2093329429626465
# 1.3226670026779175
# 1.3226670026779175
# 1.3259999752044678
# 1.3259999752044678
# 1.3760000467300415
# 1.3760000467300415
# 1.4606670141220093
# 1.4606670141220093
# 1.3533329963684082
# 1.3533329963684082
# 1.3480000495910645
# 1.3480000495910645
# 1.399999976158142
# 1.399999976158142
# 1.4193329811096191
# 1.4193329811096191
# 1.3966670036315918
# 1.3966670036315918
# 1.3700000047683716
# 1.3700000047683716
# 1.3813329935073853
# 1.3813329935073853
# 1.3566670417785645
# 1.3566670417785645
# 1.329332947731018
# 1.329332947731018
# 1.3946670293807983
# 1.3946670293807983
# ...

# %%
cerebro.addstrategy(testLog)
# Out:
# 3

# %%
cerebro.run()
# Out:
# 1.5926669836044312
# 1.5926669836044312
# 2010-06-29 00:00:00|1.5926669836044312
# 1.5886670351028442
# 1.5886670351028442
# 2010-06-30 00:00:00|1.5886670351028442
# 1.4639999866485596
# 1.4639999866485596
# 2010-07-01 00:00:00|1.4639999866485596
# 1.2799999713897705
# 1.2799999713897705
# 2010-07-02 00:00:00|1.2799999713897705
# 1.0740000009536743
# 1.0740000009536743
# 2010-07-06 00:00:00|1.0740000009536743
# 1.053333044052124
# 1.053333044052124
# 2010-07-07 00:00:00|1.053333044052124
# 1.1640000343322754
# 1.1640000343322754
# 2010-07-08 00:00:00|1.1640000343322754
# 1.159999966621399
# 1.159999966621399
# 2010-07-09 00:00:00|1.159999966621399
# 1.136667013168335
# 1.136667013168335
# 2010-07-12 00:00:00|1.136667013168335
# 1.2093329429626465
# 1.2093329429626465
# 2010-07-13 00:00:00|1.2093329429626465
# 1.3226670026779175
# 1.3226670026779175
# 2010-07-14 00:00:00|1.3226670026779175
# 1.3259999752044678
# 1.3259999752044678
# 2010-07-15 00:00:00|1.3259999752044678
# ...
